# %%
from pandas import DataFrame
import pandas as pd

# %%
sf_df = pd.read_csv('PDI_2016.csv')
sf_df.head()
# Out:
#    IncidntNum        Category                                Descript  \
# 0   160021160    PROSTITUTION  INMATE/KEEPER OF HOUSE OF PROSTITUTION
# 1   160021160    PROSTITUTION                       HUMAN TRAFFICKING
# 2   160021160    PROSTITUTION        SOLICITS FOR ACT OF PROSTITUTION
# 3   160021160  OTHER OFFENSES  MASSAGE ESTABLISHMENT PERMIT VIOLATION
# 4   160021160    NON-CRIMINAL                  SEARCH WARRANT SERVICE
#
#   DayOfWeek                    Date   Time PdDistrict      Resolution  \
# 0    Friday  01/08/2016 12:00:00 AM  12:00    CENTRAL  ARREST, BOOKED
# 1    Friday  01/08/2016 12:00:00 AM  12:00    CENTRAL  ARREST, BOOKED
# 2    Friday  01/08/2016 12:00:00 AM  12:00    CENTRAL  ARREST, BOOKED
# 3    Friday  01/08/2016 12:00:00 AM  12:00    CENTRAL  ARREST, BOOKED
# 4    Friday  01/08/2016 12:00:00 AM  12:00    CENTRAL  ARREST, BOOKED
#
#                   Address           X          Y  \
# 0  300 Block of KEARNY ST -122.404195  37.791226
# 1  300 Block of KEARNY ST -122.404195  37.791226
# 2  300 Block of KEARNY ST -122.404195  37.791226
# 3  300 Block of KEARNY ST -122.404195  37.791226
# 4  300 Block of KEARNY ST -122.404195  37.791226
#
#                                 Location            PdId
# 0  (37.7912255174119, -122.404195424821)  16002116013010
# 1  (37.7912255174119, -122.404195424821)  16002116013045
# 2  (37.7912255174119, -122.404195424821)  16002116013060
# 3  (37.7912255174119, -122.404195424821)  16002116030011
# 4  (37.7912255174119, -122.404195424821)  16002116075025

# %%
sf_df[sf_df.Category == 'DISORDERLY CONDUCT'].head(n=10)
# Out:
#       IncidntNum            Category  \
# 274    160043493  DISORDERLY CONDUCT
# 506    160030569  DISORDERLY CONDUCT
# 706    160217052  DISORDERLY CONDUCT
# 873    160219876  DISORDERLY CONDUCT
# 896    160220243  DISORDERLY CONDUCT
# 1142   160224734  DISORDERLY CONDUCT
# 1348   160226702  DISORDERLY CONDUCT
# 1360   160226821  DISORDERLY CONDUCT
# 1615   160232044  DISORDERLY CONDUCT
# 1950   160235139  DISORDERLY CONDUCT
#
#                                               Descript  DayOfWeek  \
# 274                         COMMITTING PUBLIC NUISANCE   Saturday
# 506                         COMMITTING PUBLIC NUISANCE    Tuesday
# 706                     DISTURBING THE PEACE, FIGHTING    Tuesday
# 873   MAINTAINING A PUBLIC NUISANCE AFTER NOTIFICATION    Tuesday
# 896                      MAINTAINING A PUBLIC NUISANCE  Wednesday
# 1142                    DISTURBING THE PEACE, FIGHTING   Thursday
# 1348                        COMMITTING PUBLIC NUISANCE     Friday
# 1360                    DISTURBING THE PEACE, FIGHTING     Friday
# 1615                        COMMITTING PUBLIC NUISANCE     Sunday
# 1950                        COMMITTING PUBLIC NUISANCE     Monday
#
#                         Date   Time  PdDistrict      Resolution  \
# 274   01/16/2016 12:00:00 AM  07:40    SOUTHERN            NONE
# 506   01/12/2016 12:00:00 AM  05:48  TENDERLOIN  ARREST, BOOKED
# 706   03/15/2016 12:00:00 AM  02:15    SOUTHERN            NONE
# 873   03/15/2016 12:00:00 AM  22:15     MISSION  ARREST, BOOKED
# 896   03/16/2016 12:00:00 AM  06:50        PARK  ARREST, BOOKED
# 1142  03/17/2016 12:00:00 AM  15:35     BAYVIEW            NONE
# 1348  03/18/2016 12:00:00 AM  10:15     MISSION  ARREST, BOOKED
# 1360  03/18/2016 12:00:00 AM  11:03    RICHMOND            NONE
# 1615  03/20/2016 12:00:00 AM  00:20    SOUTHERN            NONE
# 1950  03/21/2016 12:00:00 AM  09:50     MISSION            NONE
#
#                          Address           X          Y  \
# 274         5TH ST / HARRISON ST -122.401846  37.779032
# 506        300 Block of ELLIS ST -122.411966  37.784914
# 706      1500 Block of MARKET ST -122.419842  37.774823
# 873          18TH ST / CASTRO ST -122.435003  37.760888
# 896         500 Block of COLE ST -122.450242  37.770054
# 1142  MANSELL ST / GOETTINGEN ST -122.404018  37.720768
# 1348    300 Block of DIVISION ST -122.409529  37.769070
# 1360        600 Block of 32ND AV -122.491957  37.776877
# 1615     1000 Block of FOLSOM ST -122.405834  37.778255
# 1950   SAN BRUNO AV / ALAMEDA ST -122.405829  37.768475
#
#                                    Location            PdId
# 274   (37.7790324136251, -122.401846367522)  16004349319010
# 506   (37.7849141859562, -122.411965795229)  16003056919010
# 706   (37.7748226184309, -122.419842305148)  16021705219024
# 873   (37.7608878061194, -122.435002864298)  16021987627110
# 896   (37.7700540212914, -122.450242113384)  16022024327100
# 1142  (37.7207681881298, -122.404017710661)  16022473419024
# 1348  (37.7690697135105, -122.409528901583)  16022670219010
# 1360  (37.7768766735218, -122.491956779206)  16022682119024
# 1615   (37.778254811523, -122.405834032593)  16023204419010
# 1950  (37.7684749112706, -122.405828840501)  16023513919010

# %%
sf_df.Category.unique()
# Out:
# array(['PROSTITUTION', 'OTHER OFFENSES', 'NON-CRIMINAL', 'LARCENY/THEFT',
#        'WARRANTS', 'DRUG/NARCOTIC', 'SECONDARY CODES', 'BURGLARY',
#        'VEHICLE THEFT', 'ASSAULT', 'VANDALISM', 'ROBBERY', 'FRAUD',
#        'MISSING PERSON', 'SUSPICIOUS OCC', 'STOLEN PROPERTY',
#        'DRIVING UNDER THE INFLUENCE', 'WEAPON LAWS', 'DRUNKENNESS',
#        'TRESPASS', 'BAD CHECKS', 'FORGERY/COUNTERFEITING',
#        'SEX OFFENSES, FORCIBLE', 'DISORDERLY CONDUCT', 'RECOVERED VEHICLE',
#        'RUNAWAY', 'ARSON', 'LOITERING', 'LIQUOR LAWS', 'KIDNAPPING',
#        'EXTORTION', 'FAMILY OFFENSES', 'EMBEZZLEMENT', 'BRIBERY',
#        'SEX OFFENSES, NON FORCIBLE', 'PORNOGRAPHY/OBSCENE MAT', 'SUICIDE',
#        'GAMBLING', 'TREA'], dtype=object)

# %% [markdown]
# ## Filter relevant features

# %%
crimes_tourist_dont_care = [
    'OTHER OFFENSES', 
    'NON-CRIMINAL', 
    'WARRANTS',
    'SECONDARY CODES', 
    'BURGLARY',
    'VANDALISM', 
    'FRAUD',
    'SUSPICIOUS OCC', 
    'DRUNKENNESS',
    'TRESPASS', 
    'BAD CHECKS', 
    'FORGERY/COUNTERFEITING',
    'DISORDERLY CONDUCT', 
    'RECOVERED VEHICLE',
    'RUNAWAY', 
    'LOITERING', 
    'LIQUOR LAWS',
    'EXTORTION', 
    'FAMILY OFFENSES', 
    'EMBEZZLEMENT', 
    'BRIBERY',
    'SEX OFFENSES, NON FORCIBLE', 
    'PORNOGRAPHY/OBSCENE MAT', 
    'SUICIDE',
    'GAMBLING', 
    'TREA'
]

# %%
for crime in crimes_tourist_dont_care:
    
    sf_df = sf_df[sf_df.Category.str.contains(crime) == False]

# %%
sf_df.Category.unique()
# Out:
# array(['PROSTITUTION', 'LARCENY/THEFT', 'DRUG/NARCOTIC', 'VEHICLE THEFT',
#        'ASSAULT', 'ROBBERY', 'MISSING PERSON', 'STOLEN PROPERTY',
#        'DRIVING UNDER THE INFLUENCE', 'WEAPON LAWS',
#        'SEX OFFENSES, FORCIBLE', 'ARSON', 'KIDNAPPING'], dtype=object)
